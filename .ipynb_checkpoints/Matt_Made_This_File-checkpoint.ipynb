# %%
#import the GEOparse module which can handle the soft file
import GEOparse
#import the pandas module for dataframe management downstream.
import pandas as pd

#this will read the file into an object of type GSE object
gse = GEOparse.get_GEO(filepath="./GSE10245_family.soft.gz")
# Out:
# 18-Nov-2019 16:17:53 INFO GEOparse - Parsing ./GSE10245_family.soft.gz:
# 18-Nov-2019 16:17:53 DEBUG GEOparse - DATABASE: GeoMiame
# 18-Nov-2019 16:17:53 DEBUG GEOparse - SERIES: GSE10245
# 18-Nov-2019 16:17:53 DEBUG GEOparse - PLATFORM: GPL570
# 18-Nov-2019 16:17:54 DEBUG GEOparse - SAMPLE: GSM258551
# 18-Nov-2019 16:17:54 DEBUG GEOparse - SAMPLE: GSM258552
# 18-Nov-2019 16:17:54 DEBUG GEOparse - SAMPLE: GSM258553
# 18-Nov-2019 16:17:54 DEBUG GEOparse - SAMPLE: GSM258554
# 18-Nov-2019 16:17:55 DEBUG GEOparse - SAMPLE: GSM258555
# 18-Nov-2019 16:17:55 DEBUG GEOparse - SAMPLE: GSM258556
# 18-Nov-2019 16:17:55 DEBUG GEOparse - SAMPLE: GSM258557
# 18-Nov-2019 16:17:55 DEBUG GEOparse - SAMPLE: GSM258558
# 18-Nov-2019 16:17:55 DEBUG GEOparse - SAMPLE: GSM258559
# 18-Nov-2019 16:17:55 DEBUG GEOparse - SAMPLE: GSM258560
# 18-Nov-2019 16:17:55 DEBUG GEOparse - SAMPLE: GSM258561
# 18-Nov-2019 16:17:55 DEBUG GEOparse - SAMPLE: GSM258562
# ...

# %%
#gse.gsms creates a dictionary with all samples from the Soft file.
#each sample is a GSM object.
gse.gsms
# Out:
# {'GSM258551': <SAMPLE: GSM258551>,
#  'GSM258552': <SAMPLE: GSM258552>,
#  'GSM258553': <SAMPLE: GSM258553>,
#  'GSM258554': <SAMPLE: GSM258554>,
#  'GSM258555': <SAMPLE: GSM258555>,
#  'GSM258556': <SAMPLE: GSM258556>,
#  'GSM258557': <SAMPLE: GSM258557>,
#  'GSM258558': <SAMPLE: GSM258558>,
#  'GSM258559': <SAMPLE: GSM258559>,
#  'GSM258560': <SAMPLE: GSM258560>,
#  'GSM258561': <SAMPLE: GSM258561>,
#  'GSM258562': <SAMPLE: GSM258562>,
#  'GSM258563': <SAMPLE: GSM258563>,
#  'GSM258564': <SAMPLE: GSM258564>,
#  'GSM258565': <SAMPLE: GSM258565>,
#  'GSM258566': <SAMPLE: GSM258566>,
#  'GSM258567': <SAMPLE: GSM258567>,
#  'GSM258568': <SAMPLE: GSM258568>,
#  'GSM258569': <SAMPLE: GSM258569>,
#  'GSM258570': <SAMPLE: GSM258570>,
#  'GSM258571': <SAMPLE: GSM258571>,
#  'GSM258572': <SAMPLE: GSM258572>,
#  'GSM258573': <SAMPLE: GSM258573>,
#  'GSM258574': <SAMPLE: GSM258574>,
#  'GSM258575': <SAMPLE: GSM258575>,
#  'GSM258576': <SAMPLE: GSM258576>,
#  'GSM258577': <SAMPLE: GSM258577>,
# ...

# %%
#this creates a dictionary with all platforms in the GSE.
#I'm not certain what a platform is?
gse.gpls
# Out:
# {'GPL570': <PLATFORM: GPL570>}

# %%
#shows metadata regarding where the samples come from, when the 
#dataset was made, etc.
gse.show_metadata()
# Out:
# !Series_title = Gene expression differences between adenocarcinoma and squamous cell carcinoma in human NSCLC
# !Series_geo_accession = GSE10245
# !Series_status = Public on Oct 01 2009
# !Series_submission_date = Jan 23 2008
# !Series_last_update_date = Mar 25 2019
# !Series_pubmed_id = 18486272
# !Series_summary = Non-small cell lung cancer (NSCLC) can be classified into the major subtypes adenocarcinoma (AC) and squamous cell carcinoma (SCC) subtypes. Although explicit molecular, histological and clinical characteristics have been reported for both subtypes, no specific therapy exists so far. However, the characterization of suitable molecular targets holds great promises to develop novel therapies in NSCLC. In the present study, global gene expression profiling of 58 human high grade NSCLC specimens revealed large transcriptomic differences between AC and SCC subtypes: More than 1.700 genes were found to be differentially expressed.
# ...

# %%
gse.get_accession()
#accession name coming from the soft file
# Out:
# 'GSE10245'

# %%
#gse.gsms["GSM258551"].columns
pivoted_samples = gse.pivot_samples("VALUE")
pivoted_samples.head()
# Out:
# name       GSM258551  GSM258552  GSM258553  GSM258554  GSM258555  GSM258556  \
# ID_REF
# 1007_s_at   9.129905   9.843349   9.730661   9.032165  10.281793   9.154551
# 1053_at     8.034022   7.973332   8.834045   7.723965   9.040800   8.792375
# 117_at      3.564520   4.994852   5.066018   4.958580   4.951835   6.428274
# 121_at      4.746490   5.197306   5.234618   6.078180   5.205632   5.009848
# 1255_g_at   2.320698   2.248520   2.259504   2.262787   2.207531   2.322618
#
# name       GSM258557  GSM258558  GSM258559  GSM258560  ...  GSM258599  \
# ID_REF                                                 ...
# 1007_s_at   8.063788   8.881805   9.039005  10.643545  ...   9.628212
# 1053_at     8.093354   7.575620   8.438594   9.142260  ...   9.215567
# 117_at      7.364676   4.659326   6.643723   5.368356  ...   5.183919
# 121_at      5.533000   5.362637   5.210988   5.195820  ...   5.202508
# 1255_g_at   2.656929   2.255955   2.266399   2.246563  ...   2.248392
#
# ...

# %%
gse.phenotype_data
# Out:
#                    title geo_accession                 status submission_date  \
# GSM258551    NSCLC_AC_10     GSM258551  Public on Oct 01 2009     Jan 23 2008
# GSM258552    NSCLC_AC_16     GSM258552  Public on Oct 01 2009     Jan 23 2008
# GSM258553   NSCLC_SCC_22     GSM258553  Public on Oct 01 2009     Jan 23 2008
# GSM258554    NSCLC_AC_24     GSM258554  Public on Oct 01 2009     Jan 23 2008
# GSM258555   NSCLC_SCC_25     GSM258555  Public on Oct 01 2009     Jan 23 2008
# GSM258556   NSCLC_SCC_30     GSM258556  Public on Oct 01 2009     Jan 23 2008
# GSM258557   NSCLC_SCC_37     GSM258557  Public on Oct 01 2009     Jan 23 2008
# GSM258558    NSCLC_AC_40     GSM258558  Public on Oct 01 2009     Jan 23 2008
# GSM258559    NSCLC_AC_49     GSM258559  Public on Oct 01 2009     Jan 23 2008
# GSM258560    NSCLC_AC_51     GSM258560  Public on Oct 01 2009     Jan 23 2008
# GSM258561    NSCLC_AC_53     GSM258561  Public on Oct 01 2009     Jan 23 2008
# ...

# %%
gse.annotate_and_average #command doesn't appear to exist, but is in the documentation?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-34f3f96e0e54> in <module>
# ----> 1 gse.annotate_and_average
#
# AttributeError: 'GSE' object has no attribute 'annotate_and_average'

# %%
pivoted_samples.transpose()
# Out:
# ID_REF     1007_s_at   1053_at    117_at    121_at  1255_g_at   1294_at  \
# name
# GSM258551   9.129905  8.034022  3.564520  4.746490   2.320698  5.519153
# GSM258552   9.843349  7.973332  4.994852  5.197306   2.248520  5.081258
# GSM258553   9.730661  8.834045  5.066018  5.234618   2.259504  4.657257
# GSM258554   9.032165  7.723965  4.958580  6.078180   2.262787  4.535683
# GSM258555  10.281793  9.040800  4.951835  5.205632   2.207531  3.731919
# GSM258556   9.154551  8.792375  6.428274  5.009848   2.322618  4.964672
# GSM258557   8.063788  8.093354  7.364676  5.533000   2.656929  5.794959
# GSM258558   8.881805  7.575620  4.659326  5.362637   2.255955  5.416322
# GSM258559   9.039005  8.438594  6.643723  5.210988   2.266399  5.627705
# GSM258560  10.643545  9.142260  5.368356  5.195820   2.246563  4.174514
# GSM258561   8.475739  7.059735  5.232265  5.201818   2.262974  4.725232
# GSM258562   8.731395  8.323439  7.493878  5.159295   2.509950  4.340654
# ...

# %%
pivoted_samples.rename_axis("Gene_Locus")
# Out:
# name                  GSM258551  GSM258552  GSM258553  GSM258554  GSM258555  \
# Gene_Locus
# 1007_s_at              9.129905   9.843349   9.730661   9.032165  10.281793
# 1053_at                8.034022   7.973332   8.834045   7.723965   9.040800
# 117_at                 3.564520   4.994852   5.066018   4.958580   4.951835
# 121_at                 4.746490   5.197306   5.234618   6.078180   5.205632
# 1255_g_at              2.320698   2.248520   2.259504   2.262787   2.207531
# ...                         ...        ...        ...        ...        ...
# AFFX-r2-Ec-bioC-5_at  10.730983   9.719266   9.101115   9.763076   9.651785
# AFFX-r2-Ec-bioD-3_at  13.599488  12.847711  12.384142  12.969199  12.924465
# AFFX-r2-Ec-bioD-5_at  13.031726  12.250033  11.798363  12.307684  12.243207
# AFFX-r2-P1-cre-3_at   15.028729  14.440756  14.439887  14.557363  14.612223
# AFFX-r2-P1-cre-5_at   14.586347  14.072366  14.011392  14.162145  14.122751
#
# ...
